# %%
import pandas as pd
import os
from pydataset import data
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# check
# data('iris').head()
df_iris = data('iris')

# check
# first 3 rows
df_iris.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %%
# rows, col
df_iris.shape
# Out:
# (150, 5)

# %%
# column names
df_iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
# column Data types
df_iris.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
# summary statistics
df_iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Google sheet

sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df_gs = pd.read_csv(csv_export_url)
# first 3 rows
df_gs.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# rows, col
df_gs.shape
# Out:
# (891, 12)

# %%
# col names
df_gs.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# data types
df_gs.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# summary stats
df_gs.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Display unique values for each categorical variable
obj_gs = df_gs.select_dtypes(exclude='number').columns
obj_gs

# for col in df_gs.select_dtypes(include='object').columns:
#     print(f"Unique values for {col}:")
#     print(df_gs[col].unique())
#     print("\n")
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df_xcel = pd.read_excel('train.xlsx')
df_xcel.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
# save a sample
df_xcel_sample = df_xcel.head(100)

# %%
# rows of OG df_xcel
rows, columns = df_xcel_sample.shape

# Print the number of rows
print(rows)
# Out:
# 100

# %%
# first 5 column names
df_xcel_sample.columns[:5]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex'], dtype='object')

# %%
# column type objects
obj_xcel_sample = df_xcel_sample.select_dtypes(exclude='number').columns
obj_xcel_sample
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
# compute range for each numeric
# pull out just number col and assign to variable
numeric_columns = df_xcel_sample.select_dtypes(include='number').columns

# check
# numeric_columns

# Compute and print the range for each numeric variable
for column in numeric_columns:
    # assign variable for delta
    column_range = df_xcel_sample[column].max() - df_xcel_sample[column].min()
    print(f"Range for {column}: {column_range}")
# Out:
# Range for PassengerId: 99
# Range for Survived: 1
# Range for Pclass: 2
# Range for Age: 70.17
# Range for SibSp: 5
# Range for Parch: 5
# Range for Fare: 255.775

# %% [markdown]
# Create get_titanic_data function
# def get_titanic_data():
#     filename = "titanic.csv"
#
#     if os.path.isfile(filename):
#         return pd.read_csv(filename)
#     else:
#         # Create connection url
#         url = get_db_url('titanic_db')
#
#         # Read the SQL query into a dataframe
#         df = pd.read_sql(('SELECT * FROM passengers'), url)
#
#         # Write that dataframe to disk for later. Called "caching" the data for later.
#         df.to_csv(filename)
#
#         # Return the dataframe to the calling code
#         return df

# %%
import env
import os

from acquire import get_titanic_data

# %% [markdown]
# read titanic db
# url = env.get_db_url('titanic_db')

# %% [markdown]
# pd.read_sql('show tables', url)

# %% [markdown]
# df_titanic=pd.read_sql('select * from passengers',url)
# df_titanic.head()

# %%
df_titanic = get_titanic_data()

# %%
df_titanic.head()
# Out:
#    Unnamed: 0  passenger_id  survived  pclass     sex   age  sibsp  parch  \
# 0           0             0         0       3    male  22.0      1      0
# 1           1             1         1       1  female  38.0      1      0
# 2           2             2         1       3  female  26.0      0      0
# 3           3             3         1       1  female  35.0      1      0
# 4           4             4         0       3    male  35.0      0      0
#
#       fare embarked  class deck  embark_town  alone
# 0   7.2500        S  Third  NaN  Southampton      0
# 1  71.2833        C  First    C    Cherbourg      0
# 2   7.9250        S  Third  NaN  Southampton      1
# 3  53.1000        S  First    C  Southampton      0
# 4   8.0500        S  Third  NaN  Southampton      1

# %%
from acquire import get_iris_data

# %%
df_iris = get_iris_data()
df_iris.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %%
from acquire import get_telco_data

# %%
df_telco = get_telco_data()

# %%
df_telco.head()
# Out:
#    Unnamed: 0  payment_type_id  internet_service_type_id  contract_type_id  \
# 0           0                2                         1                 2
# 1           1                2                         1                 1
# 2           2                1                         2                 1
# 3           3                1                         2                 1
# 4           4                2                         2                 1
#
#   customer_id  gender  senior_citizen partner dependents  tenure  ...  \
# 0  0002-ORFBO  Female               0     Yes        Yes       9  ...
# 1  0003-MKNFE    Male               0      No         No       9  ...
# 2  0004-TLHLJ    Male               0      No         No       4  ...
# 3  0011-IGKFF    Male               1     Yes         No      13  ...
# 4  0013-EXCHZ  Female               1     Yes         No       3  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# ...
